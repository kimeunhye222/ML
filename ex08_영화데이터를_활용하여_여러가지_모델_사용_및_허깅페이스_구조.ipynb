# %% [markdown]
# ### 여러가지 순환 신경망 사용
# - 영화 리뷰데이터를 활용하여 여러가지 순환신경망을 사용해보고 더 나아가서 허깅페이스에서 제공하는 transformer기반의 모델을 상요해보기
# - simpleRNN, LSTM, GRU 등 여러가지 모델 사

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 드라이브 마운트 진행
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 작업 디렉토리 변경
# %cd /content/drive/MyDrive/Colab Notebooks/딥러닝
# Out:
# /content/drive/MyDrive/Colab Notebooks/딥러닝

# %%
naver_train_txt = pd.read_csv('./data/ratings_train.txt', delimiter='\t')
naver_test_txt = pd.read_csv('./data/ratings_test.txt', delimiter='\t')

# %%
naver_train_txt.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# 데이터 정보 확인
naver_train_txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
# 결측치 제거
naver_train_txt = naver_train_txt.dropna()
# naver_train_txt.dropna(inplace=True)
# dropna() : 결측치를 제거하는 기능
naver_test_txt = naver_test_txt.dropna()

# %%
naver_train_txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149995 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        149995 non-null  int64
#  1   document  149995 non-null  object
#  2   label     149995 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ MB

# %%
# 문제데이터와 정답데이터 분리
train_txt = naver_train_txt['document']
test_txt = naver_test_txt['document']
y_train = naver_train_txt['label']
y_test = naver_test_txt['label']

# %%
train_txt
# Out:
# 0                                       아 더빙.. 진짜 짜증나네요 목소리
# 1                         흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                             교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
#                                 ...
# 149995                                  인간이 문제지.. 소는 뭔죄인가..
# 149996                                        평점이 너무 낮아서...
# 149997                      이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?
# 149998                          청춘 영화의 최고봉.방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 149995, dtype: object

# %% [markdown]
# ### 데이터 전처리
# - 텍스트 기반의 데이터를 사용할 때는 불용어처리, 오탈자 교정, 스페이스바 교정, 이모지 제거 등 전처리를 1차로 작업한 후 토큰화를 통해 내가 원하는 데이터를 분리하여 단어를 추출하고 임베딩 기법을 통해 의미를 잘 전달할 수 있도록 수치화 하는 것이 정석

# %%
# 문장데이터를 수치로 변활할 수 있도록 도와주는 도구 불러오기
from tensorflow.keras.layers import TextVectorization

# %%
# 벡터화 도구 생성
vectorizer = TextVectorization(
    max_tokens = 5000, # 사용할 최대 단어 토큰 수 제한(빈도수 기반으로 하기 때문에 빈도가 많은 순으로 생성)
    output_mode = 'int', # 빈도 기반으로 변환될 타입 설정
    standardize = 'lower_and_strip_punctuation', # 대문자를 소문자로 변경, 마침표 제거 기능 (간단한 전처리)
    output_sequence_length = 10 # 문장의 길이를 제한 (부족하면 채우고 길면 자르는 기법)
)

# %%
# 단어 학습 진행 (단어사전 생성)
vectorizer.adapt(train_txt)

# %%
# 단어사전 개수 확인
vectorizer.vocabulary_size()
# Out:
# 5000

# %%
# 단어사전 확인 방법
vectorizer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  np.str_('영화'),
#  np.str_('너무'),
#  np.str_('정말'),
#  np.str_('진짜'),
#  np.str_('이'),
#  np.str_('왜'),
#  np.str_('그냥'),
#  np.str_('이런'),
#  np.str_('더'),
#  np.str_('수'),
#  np.str_('영화를'),
#  np.str_('잘'),
#  np.str_('다'),
#  np.str_('보고'),
#  np.str_('좀'),
#  np.str_('영화는'),
#  np.str_('영화가'),
#  np.str_('그'),
#  np.str_('본'),
#  np.str_('최고의'),
#  np.str_('봤는데'),
#  np.str_('ㅋㅋ'),
#  np.str_('없는'),
#  np.str_('내가'),
#  np.str_('이건'),
#  np.str_('없다'),
#  np.str_('이렇게'),
#  np.str_('드라마'),
#  np.str_('완전'),
#  np.str_('평점'),
#  np.str_('이거'),
#  np.str_('있는'),
#  np.str_('좋은'),
#  np.str_('이게'),
#  np.str_('참'),
#  np.str_('아'),
#  np.str_('평점이'),
#  np.str_('보는'),
#  np.str_('내'),
#  np.str_('연기'),
#  np.str_('다시'),
#  np.str_('그리고'),
#  np.str_('역시'),
#  np.str_('쓰레기'),
#  np.str_('많이'),
#  np.str_('것'),
#  np.str_('최고'),
#  np.str_('난'),
#  np.str_('스토리'),
#  np.str_('재밌게'),
#  np.str_('한'),
#  np.str_('없고'),
#  np.str_('하는'),
#  np.str_('또'),
#  np.str_('꼭'),
#  np.str_('보면'),
#  np.str_('가장'),
#  np.str_('아깝다'),
#  np.str_('ㅋㅋㅋ'),
#  np.str_('ㅠㅠ'),
#  np.str_('마지막'),
#  np.str_('영화다'),
#  np.str_('뭐'),
#  np.str_('무슨'),
#  np.str_('ㅡㅡ'),
#  np.str_('ㅋ'),
#  np.str_('10점'),
#  np.str_('같은'),
#  np.str_('하지만'),
#  np.str_('볼'),
#  np.str_('별로'),
#  np.str_('끝까지'),
#  np.str_('작품'),
#  np.str_('솔직히'),
#  np.str_('대한'),
#  np.str_('안'),
#  np.str_('만든'),
#  np.str_('넘'),
#  np.str_('봐도'),
#  np.str_('전혀'),
#  np.str_('말이'),
#  np.str_('아주'),
#  np.str_('영화의'),
#  np.str_('내내'),
#  np.str_('지금'),
#  np.str_('같다'),
#  np.str_('ㅎㅎ'),
#  np.str_('최악의'),
#  np.str_('뭔가'),
#  np.str_('좋다'),
#  np.str_('할'),
#  np.str_('하고'),
#  np.str_('다른'),
#  np.str_('재미'),
#  np.str_('있다'),
#  np.str_('그래도'),
#  np.str_('않고'),
#  np.str_('재미있게'),
#  np.str_('어떻게'),
#  np.str_('많은'),
#  np.str_('하나'),
#  np.str_('연기가'),
#  np.str_('별'),
#  np.str_('중'),
#  np.str_('듯'),
#  np.str_('감독'),
#  np.str_('이걸'),
#  np.str_('재밌다'),
#  np.str_('굿'),
#  np.str_('와'),
#  np.str_('아니라'),
#  np.str_('연기도'),
#  np.str_('이야기'),
#  np.str_('모두'),
#  np.str_('1점'),
#  np.str_('아니다'),
#  np.str_('봤다'),
#  np.str_('근데'),
#  np.str_('아름다운'),
#  np.str_('보다가'),
#  np.str_('스토리가'),
#  np.str_('나는'),
#  np.str_('명작'),
#  np.str_('때문에'),
#  np.str_('계속'),
#  np.str_('감동'),
#  np.str_('제대로'),
#  np.str_('나오는'),
#  np.str_('시간'),
#  np.str_('느낌'),
#  np.str_('제일'),
#  np.str_('영화에'),
#  np.str_('내용도'),
#  np.str_('모든'),
#  np.str_('내용이'),
#  np.str_('않은'),
#  np.str_('차라리'),
#  np.str_('아직도'),
#  np.str_('아니고'),
#  np.str_('때'),
#  np.str_('재미없다'),
#  np.str_('액션'),
#  np.str_('아닌'),
#  np.str_('감독이'),
#  np.str_('감독의'),
#  np.str_('시간이'),
#  np.str_('영화라고'),
#  np.str_('스토리도'),
#  np.str_('보다'),
#  np.str_('않는'),
#  np.str_('특히'),
#  np.str_('만드는'),
#  np.str_('여운이'),
#  np.str_('한번'),
#  np.str_('도대체'),
#  np.str_('재미도'),
#  np.str_('오랜만에'),
#  np.str_('영화입니다'),
#  np.str_('보면서'),
#  np.str_('딱'),
#  np.str_('나도'),
#  np.str_('싶다'),
#  np.str_('배우들'),
#  np.str_('마지막에'),
#  np.str_('아까운'),
#  np.str_('연출'),
#  np.str_('나름'),
#  np.str_('처음'),
#  np.str_('좋았다'),
#  np.str_('좋고'),
#  np.str_('걍'),
#  np.str_('없이'),
#  np.str_('지루하고'),
#  np.str_('배우들의'),
#  np.str_('봤습니다'),
#  np.str_('그런'),
#  np.str_('줄'),
#  np.str_('좋아하는'),
#  np.str_('진심'),
#  np.str_('재밌어요'),
#  np.str_('이영화'),
#  np.str_('남는'),
#  np.str_('주는'),
#  np.str_('보기'),
#  np.str_('절대'),
#  np.str_('못'),
#  np.str_('1점도'),
#  np.str_('얼마나'),
#  np.str_('이제'),
#  np.str_('이해가'),
#  np.str_('요즘'),
#  np.str_('연기는'),
#  np.str_('내용'),
#  np.str_('없음'),
#  np.str_('뻔한'),
#  np.str_('보는내내'),
#  np.str_('영화로'),
#  np.str_('개인적으로'),
#  np.str_('조금'),
#  np.str_('짱'),
#  np.str_('영화도'),
#  np.str_('최고다'),
#  np.str_('ㅋㅋㅋㅋ'),
#  np.str_('그저'),
#  np.str_('재미가'),
#  np.str_('기억에'),
#  np.str_('보세요'),
#  np.str_('생각이'),
#  np.str_('엄청'),
#  np.str_('아무리'),
#  np.str_('봤던'),
#  np.str_('너무나'),
#  np.str_('멋진'),
#  np.str_('되는'),
#  np.str_('전'),
#  np.str_('대박'),
#  np.str_('한국'),
#  np.str_('최악'),
#  np.str_('괜찮은'),
#  np.str_('매우'),
#  np.str_('사람이'),
#  np.str_('게'),
#  np.str_('위해'),
#  np.str_('그렇게'),
#  np.str_('하나도'),
#  np.str_('제발'),
#  np.str_('것이'),
#  np.str_('있고'),
#  np.str_('싶은'),
#  np.str_('두'),
#  np.str_('주인공'),
#  np.str_('극장에서'),
#  np.str_('함께'),
#  np.str_('건'),
#  np.str_('인생'),
#  np.str_('위한'),
#  np.str_('안되는'),
#  np.str_('결국'),
#  np.str_('배우'),
#  np.str_('지루한'),
#  np.str_('마음이'),
#  np.str_('그나마'),
#  np.str_('가슴이'),
#  np.str_('돈'),
#  np.str_('내용은'),
#  np.str_('같이'),
#  np.str_('모르겠다'),
#  np.str_('갈수록'),
#  np.str_('ㅜㅜ'),
#  np.str_('못한'),
#  np.str_('ㅎ'),
#  np.str_('개'),
#  np.str_('된'),
#  np.str_('뭘'),
#  np.str_('지루하다'),
#  np.str_('않는다'),
#  np.str_('코미디'),
#  np.str_('그래서'),
#  np.str_('봤어요'),
#  np.str_('것도'),
#  np.str_('재밌는'),
#  np.str_('큰'),
#  np.str_('나'),
#  np.str_('좋아요'),
#  np.str_('연기를'),
#  np.str_('한다'),
#  np.str_('어떤'),
#  np.str_('영화네요'),
#  np.str_('밖에'),
#  np.str_('ㅠ'),
#  np.str_('눈물이'),
#  np.str_('것을'),
#  np.str_('훨씬'),
#  np.str_('재밌고'),
#  np.str_('꽤'),
#  np.str_('재밌음'),
#  np.str_('거'),
#  np.str_('간만에'),
#  np.str_('나온'),
#  np.str_('영화중'),
#  np.str_('대체'),
#  np.str_('사람'),
#  np.str_('보지'),
#  np.str_('기억이'),
#  np.str_('재미없음'),
#  np.str_('어설픈'),
#  np.str_('사랑'),
#  np.str_('장면'),
#  np.str_('영화관에서'),
#  np.str_('다들'),
#  np.str_('good'),
#  np.str_('저'),
#  np.str_('아니'),
#  np.str_('생각을'),
#  np.str_('누가'),
#  np.str_('대해'),
#  np.str_('진정한'),
#  np.str_('스토리는'),
#  np.str_('상당히'),
#  np.str_('정도로'),
#  np.str_('사람들이'),
#  np.str_('강추'),
#  np.str_('걸'),
#  np.str_('감동도'),
#  np.str_('결말이'),
#  np.str_('감동을'),
#  np.str_('생각보다'),
#  np.str_('우리'),
#  np.str_('느낌이'),
#  np.str_('잔잔한'),
#  np.str_('않다'),
#  np.str_('아쉽다'),
#  np.str_('감동적인'),
#  np.str_('여자'),
#  np.str_('보여주는'),
#  np.str_('배우들이'),
#  np.str_('바로'),
#  np.str_('정도'),
#  np.str_('일본'),
#  np.str_('오늘'),
#  np.str_('좋은데'),
#  np.str_('전개'),
#  np.str_('뭔'),
#  np.str_('없었다'),
#  np.str_('보니'),
#  np.str_('추천'),
#  np.str_('중간에'),
#  np.str_('주고'),
#  np.str_('스릴러'),
#  np.str_('아님'),
#  np.str_('보게'),
#  np.str_('했는데'),
#  np.str_('나와서'),
#  np.str_('영화였다'),
#  np.str_('굉장히'),
#  np.str_('우리나라'),
#  np.str_('있지만'),
#  np.str_('해서'),
#  np.str_('결말'),
#  np.str_('장면이'),
#  np.str_('원작을'),
#  np.str_('봤지만'),
#  np.str_('될'),
#  np.str_('거의'),
#  np.str_('같은데'),
#  np.str_('수작'),
#  np.str_('평점을'),
#  np.str_('졸작'),
#  np.str_('연기력'),
#  np.str_('준다'),
#  np.str_('존나'),
#  np.str_('재미는'),
#  np.str_('수준'),
#  np.str_('나의'),
#  np.str_('갑자기'),
#  np.str_('지루함'),
#  np.str_('자체가'),
#  np.str_('반전'),
#  np.str_('마음에'),
#  np.str_('같아요'),
#  np.str_('있을까'),
#  np.str_('알고'),
#  np.str_('사람들'),
#  np.str_('그러나'),
#  np.str_('영화인데'),
#  np.str_('말'),
#  np.str_('약간'),
#  np.str_('당시'),
#  np.str_('기대'),
#  np.str_('이영화를'),
#  np.str_('재밌네요'),
#  np.str_('재미있는'),
#  np.str_('있어서'),
#  np.str_('사람은'),
#  np.str_('재미있어요'),
#  np.str_('재미있다'),
#  np.str_('그런지'),
#  np.str_('그대로'),
#  np.str_('비해'),
#  np.str_('뭐야'),
#  np.str_('제가'),
#  np.str_('것은'),
#  np.str_('훌륭한'),
#  np.str_('항상'),
#  np.str_('충분히'),
#  np.str_('봐서'),
#  np.str_('하지'),
#  np.str_('저는'),
#  np.str_('뭐지'),
#  np.str_('쓰레기영화'),
#  np.str_('시리즈'),
#  np.str_('준'),
#  np.str_('없어서'),
#  np.str_('어디서'),
#  np.str_('하다'),
#  np.str_('볼만한'),
#  np.str_('새로운'),
#  np.str_('말도'),
#  np.str_('처음부터'),
#  np.str_('맘에'),
#  np.str_('기분'),
#  np.str_('한마디로'),
#  np.str_('주인공이'),
#  np.str_('일단'),
#  np.str_('수가'),
#  np.str_('가지고'),
#  np.str_('감독은'),
#  np.str_('b급'),
#  np.str_('영화임'),
#  np.str_('아까움'),
#  np.str_('봐라'),
#  np.str_('전개가'),
#  np.str_('몰입도'),
#  np.str_('이영화는'),
#  np.str_('막장'),
#  np.str_('더욱'),
#  np.str_('평점은'),
#  np.str_('이딴'),
#  np.str_('가슴'),
#  np.str_('음악'),
#  np.str_('점점'),
#  np.str_('있는데'),
#  np.str_('생각'),
#  np.str_('사랑을'),
#  np.str_('사람들은'),
#  np.str_('뭐가'),
#  np.str_('긴장감'),
#  np.str_('무조건'),
#  np.str_('다시봐도'),
#  np.str_('감동이'),
#  np.str_('생각하게'),
#  np.str_('합니다'),
#  np.str_('재미없는'),
#  np.str_('도저히'),
#  np.str_('엄청난'),
#  np.str_('아직'),
#  np.str_('뭐냐'),
#  np.str_('했다'),
#  np.str_('애니메이션'),
#  np.str_('전부'),
#  np.str_('뿐'),
#  np.str_('이것도'),
#  np.str_('봤음'),
#  np.str_('모르고'),
#  np.str_('대단한'),
#  np.str_('전형적인'),
#  np.str_('오히려'),
#  np.str_('좋네요'),
#  np.str_('재밌는데'),
#  np.str_('이야기를'),
#  np.str_('후'),
#  np.str_('해도'),
#  np.str_('평점에'),
#  np.str_('그게'),
#  np.str_('ㅉㅉ'),
#  np.str_('따뜻한'),
#  np.str_('노잼'),
#  np.str_('보는데'),
#  np.str_('듯한'),
#  np.str_('그만'),
#  np.str_('완벽한'),
#  np.str_('예전에'),
#  np.str_('만들어'),
#  np.str_('캐릭터'),
#  np.str_('제'),
#  np.str_('억지로'),
#  np.str_('액션도'),
#  np.str_('인간의'),
#  np.str_('원래'),
#  np.str_('oo'),
#  np.str_('너무너무'),
#  np.str_('배우가'),
#  np.str_('지금도'),
#  np.str_('하면'),
#  np.str_('우연히'),
#  np.str_('특유의'),
#  np.str_('음'),
#  np.str_('없어'),
#  np.str_('애니'),
#  np.str_('걸작'),
#  np.str_('말고'),
#  np.str_('3류'),
#  np.str_('처음으로'),
#  np.str_('대사'),
#  np.str_('별점'),
#  np.str_('남자'),
#  np.str_('좋겠다'),
#  np.str_('장면은'),
#  np.str_('재미있고'),
#  np.str_('아무것도'),
#  np.str_('실망'),
#  np.str_('시나리오'),
#  np.str_('못하는'),
#  np.str_('네이버'),
#  np.str_('자꾸'),
#  np.str_('재밌었다'),
#  np.str_('입니다'),
#  np.str_('물론'),
#  np.str_('이미'),
#  np.str_('원작'),
#  np.str_('없네'),
#  np.str_('몇'),
#  np.str_('유치한'),
#  np.str_('유치하고'),
#  np.str_('더럽게'),
#  np.str_('느낄'),
#  np.str_('중에'),
#  np.str_('영화보다'),
#  np.str_('봤네요'),
#  np.str_('된다'),
#  np.str_('것이다'),
#  np.str_('또한'),
#  np.str_('없네요'),
#  np.str_('저도'),
#  np.str_('영화라'),
#  np.str_('좋음'),
#  np.str_('재미없고'),
#  np.str_('낫다'),
#  np.str_('한국영화'),
#  np.str_('봄'),
#  np.str_('믿고'),
#  np.str_('돈주고'),
#  np.str_('억지'),
#  np.str_('좋았어요'),
#  np.str_('알'),
#  np.str_('스토리에'),
#  np.str_('모습이'),
#  np.str_('그의'),
#  np.str_('그닥'),
#  np.str_('알았는데'),
#  np.str_('공포영화'),
#  np.str_('이런걸'),
#  np.str_('사실'),
#  np.str_('왜이리'),
#  np.str_('아이들이'),
#  np.str_('빨리'),
#  np.str_('마음을'),
#  np.str_('눈물'),
#  np.str_('영'),
#  np.str_('연출이'),
#  np.str_('어느'),
#  np.str_('돈이'),
#  np.str_('너무나도'),
#  np.str_('공포'),
#  np.str_('저런'),
#  np.str_('이상'),
#  np.str_('영화에서'),
#  np.str_('삶을'),
#  np.str_('드라마를'),
#  np.str_('라는'),
#  np.str_('있었다'),
#  np.str_('막'),
#  np.str_('하는데'),
#  np.str_('좋아'),
#  np.str_('있음'),
#  np.str_('이야기가'),
#  np.str_('아닌가'),
#  np.str_('기대하고'),
#  np.str_('애들'),
#  np.str_('명작이다'),
#  np.str_('마치'),
#  np.str_('하게'),
#  np.str_('지금까지'),
#  np.str_('이해'),
#  np.str_('소재는'),
#  np.str_('느끼게'),
#  np.str_('그렇고'),
#  np.str_('ㅎㅎㅎ'),
#  np.str_('어릴때'),
#  np.str_('알았다'),
#  np.str_('안된다'),
#  np.str_('아니지만'),
#  np.str_('미친'),
#  np.str_('지금봐도'),
#  np.str_('확실히'),
#  np.str_('드라마가'),
#  np.str_('진부한'),
#  np.str_('전체적으로'),
#  np.str_('이젠'),
#  np.str_('않음'),
#  np.str_('이런게'),
#  np.str_('괜히'),
#  np.str_('모습을'),
#  np.str_('로맨스'),
#  np.str_('화려한'),
#  np.str_('자신의'),
#  np.str_('영화중에'),
#  np.str_('다소'),
#  np.str_('못하고'),
#  np.str_('영화였습니다'),
#  np.str_('그런데'),
#  np.str_('같습니다'),
#  np.str_('ooo'),
#  np.str_('왠지'),
#  np.str_('뭔지'),
#  np.str_('무엇보다'),
#  np.str_('날'),
#  np.str_('화이팅'),
#  np.str_('혼자'),
#  np.str_('좋았고'),
#  np.str_('이영화가'),
#  np.str_('스토리와'),
#  np.str_('만들지'),
#  np.str_('눈이'),
#  np.str_('가는'),
#  np.str_('있어'),
#  np.str_('있다는'),
#  np.str_('영화지만'),
#  np.str_('앞으로'),
#  np.str_('비슷한'),
#  np.str_('부분이'),
#  np.str_('나를'),
#  np.str_('tv'),
#  np.str_('여자가'),
#  np.str_('최악이다'),
#  np.str_('잘봤습니다'),
#  np.str_('연기에'),
#  np.str_('여전히'),
#  np.str_('모르는'),
#  np.str_('내용을'),
#  np.str_('좋았습니다'),
#  np.str_('아쉬운'),
#  np.str_('소재를'),
#  np.str_('점수'),
#  np.str_('어렸을때'),
#  np.str_('아니면'),
#  np.str_('허접한'),
#  np.str_('영상'),
#  np.str_('소재'),
#  np.str_('봐야'),
#  np.str_('했지만'),
#  np.str_('스토리를'),
#  np.str_('사람을'),
#  np.str_('좋았음'),
#  np.str_('왜이렇게'),
#  np.str_('액션은'),
#  np.str_('않았다'),
#  np.str_('매력적인'),
#  np.str_('드라마는'),
#  np.str_('있다면'),
#  np.str_('아무'),
#  np.str_('보는게'),
#  np.str_('하'),
#  np.str_('재밌었어요'),
#  np.str_('유쾌한'),
#  np.str_('역시나'),
#  np.str_('슬픈'),
#  np.str_('다만'),
#  np.str_('연기와'),
#  np.str_('순수한'),
#  np.str_('높은'),
#  np.str_('깊은'),
#  np.str_('감독님'),
#  np.str_('통해'),
#  np.str_('지난'),
#  np.str_('좋았는데'),
#  np.str_('전에'),
#  np.str_('영화이다'),
#  np.str_('보고나서'),
#  np.str_('굳'),
#  np.str_('있을'),
#  np.str_('이리'),
#  np.str_('이런영화'),
#  np.str_('볼때마다'),
#  np.str_('보기엔'),
#  np.str_('그들의'),
#  np.str_('현실을'),
#  np.str_('본다'),
#  np.str_('반전이'),
#  np.str_('눈을'),
#  np.str_('감사합니다'),
#  np.str_('옛날'),
#  np.str_('연기력이'),
#  np.str_('어이없는'),
#  np.str_('별로다'),
#  np.str_('굳이'),
#  np.str_('헐'),
#  np.str_('전기세가'),
#  np.str_('대단하다'),
#  np.str_('ㅅㅂ'),
#  np.str_('주인공의'),
#  np.str_('아닐까'),
#  np.str_('부족한'),
#  np.str_('먼저'),
#  np.str_('나오고'),
#  np.str_('귀엽고'),
#  np.str_('졸라'),
#  np.str_('있었던'),
#  np.str_('영화보고'),
#  np.str_('언제'),
#  np.str_('안하고'),
#  np.str_('생각한다'),
#  np.str_('매력이'),
#  np.str_('든다'),
#  np.str_('독특한'),
#  np.str_('같네요'),
#  np.str_('액션이'),
#  np.str_('삼류'),
#  np.str_('보여준'),
#  np.str_('끝'),
#  np.str_('과연'),
#  np.str_('개연성'),
#  np.str_('평범한'),
#  np.str_('이유가'),
#  np.str_('이런거'),
#  np.str_('아름답고'),
#  np.str_('등'),
#  np.str_('힘든'),
#  np.str_('재미없어'),
#  np.str_('재미를'),
#  np.str_('어색한'),
#  np.str_('아놔'),
#  np.str_('봤었는데'),
#  np.str_('기대를'),
#  np.str_('그런가'),
#  np.str_('감동적이고'),
#  np.str_('음악이'),
#  np.str_('봤다가'),
#  np.str_('보지마세요'),
#  np.str_('느껴지는'),
#  np.str_('나만'),
#  np.str_('추천합니다'),
#  np.str_('처음이다'),
#  np.str_('해준'),
#  np.str_('여주인공'),
#  np.str_('아름답다'),
#  np.str_('세상에'),
#  np.str_('난다'),
#  np.str_('함'),
#  np.str_('캐스팅'),
#  np.str_('참고'),
#  np.str_('사랑이'),
#  np.str_('배우의'),
#  np.str_('발연기'),
#  np.str_('the'),
#  np.str_('정말로'),
#  np.str_('재미있음'),
#  np.str_('이정도면'),
#  np.str_('마음'),
#  np.str_('귀여운'),
#  np.str_('이유는'),
#  np.str_('볼수'),
#  np.str_('남는다'),
#  np.str_('꿀잼'),
#  np.str_('저렇게'),
#  np.str_('사람의'),
#  np.str_('보이는'),
#  np.str_('그럭저럭'),
#  np.str_('티비에서'),
#  np.str_('사랑에'),
#  np.str_('노래'),
#  np.str_('감동과'),
#  np.str_('1'),
#  np.str_('처음엔'),
#  np.str_('이상한'),
#  np.str_('역대'),
#  np.str_('안됨'),
#  np.str_('볼수록'),
#  np.str_('보시길'),
#  np.str_('지루해서'),
#  np.str_('삶의'),
#  np.str_('공감이'),
#  np.str_('ㅋㅋㅋㅋㅋ'),
#  np.str_('진심으로'),
#  np.str_('아닌데'),
#  np.str_('소재가'),
#  np.str_('봤으면'),
#  np.str_('ㅡ'),
#  np.str_('해주는'),
#  np.str_('연출도'),
#  np.str_('없지만'),
#  np.str_('안되고'),
#  np.str_('신선한'),
#  np.str_('생각합니다'),
#  np.str_('살짝'),
#  np.str_('판타지'),
#  np.str_('재밌습니다'),
#  np.str_('알게'),
#  np.str_('몰라도'),
#  np.str_('나왔으면'),
#  np.str_('2점'),
#  np.str_('필요없는'),
#  np.str_('질질'),
#  np.str_('지루하지'),
#  np.str_('중간중간'),
#  np.str_('재밌었는데'),
#  np.str_('우리가'),
#  np.str_('속'),
#  np.str_('마라'),
#  np.str_('좋아서'),
#  np.str_('몰입이'),
#  np.str_('만들어진'),
#  np.str_('드는'),
#  np.str_('되었다'),
#  np.str_('그다지'),
#  np.str_('하면서'),
#  np.str_('떨어지는'),
#  np.str_('나에게'),
#  np.str_('했던'),
#  np.str_('필요없다'),
#  np.str_('시간을'),
#  np.str_('만들'),
#  np.str_('대충'),
#  np.str_('9점'),
#  np.str_('필요'),
#  np.str_('제목이'),
#  np.str_('번'),
#  np.str_('자기'),
#  np.str_('음악도'),
#  np.str_('영화냐'),
#  np.str_('않을'),
#  np.str_('않게'),
#  np.str_('사랑하는'),
#  np.str_('볼만함'),
#  np.str_('반전도'),
#  np.str_('나중에'),
#  np.str_('끝나고'),
#  np.str_('그리'),
#  np.str_('가서'),
#  np.str_('80년대'),
#  np.str_('추억의'),
#  np.str_('좋은영화'),
#  np.str_('점수를'),
#  np.str_('인생을'),
#  np.str_('이후'),
#  np.str_('어린'),
#  np.str_('쓴'),
#  np.str_('나온다'),
#  np.str_('같음'),
#  np.str_('가진'),
#  np.str_('90년대'),
#  np.str_('흠'),
#  np.str_('봐야할'),
#  np.str_('만큼'),
#  np.str_('가볍게'),
#  np.str_('제목'),
#  np.str_('슬프다'),
#  np.str_('서로'),
#  np.str_('불구하고'),
#  np.str_('부터'),
#  np.str_('기분이'),
#  np.str_('크게'),
#  np.str_('짜증나는'),
#  np.str_('여기'),
#  np.str_('언제나'),
#  np.str_('쉽게'),
#  np.str_('사랑과'),
#  np.str_('눈물을'),
#  np.str_('낮아서'),
#  np.str_('죄다'),
#  np.str_('애들이'),
#  np.str_('수도'),
#  np.str_('0점'),
#  np.str_('있게'),
#  np.str_('이제야'),
#  np.str_('엔딩'),
#  np.str_('미국'),
#  np.str_('결말은'),
#  np.str_('겁나'),
#  np.str_('하네요'),
#  np.str_('좋습니다'),
#  np.str_('재미없네'),
#  np.str_('작품이'),
#  np.str_('열심히'),
#  np.str_('소재로'),
#  np.str_('되게'),
#  np.str_('더이상'),
#  np.str_('대한민국'),
#  np.str_('단'),
#  np.str_('느낌을'),
#  np.str_('구성'),
#  np.str_('킬링타임용'),
#  np.str_('있지'),
#  np.str_('엉성한'),
#  np.str_('시대를'),
#  np.str_('밑에'),
#  np.str_('딱히'),
#  np.str_('까지'),
#  np.str_('0점은'),
#  np.str_('지금은'),
#  np.str_('웃기고'),
#  np.str_('없을'),
#  np.str_('아는'),
#  np.str_('배우들도'),
#  np.str_('ost'),
#  np.str_('재미있네요'),
#  np.str_('있습니다'),
#  np.str_('어이가'),
#  np.str_('아닌듯'),
#  np.str_('매력'),
#  np.str_('맞는'),
#  np.str_('마세요'),
#  np.str_('뛰어난'),
#  np.str_('되지'),
#  np.str_('단순한'),
#  np.str_('내인생'),
#  np.str_('지루해'),
#  np.str_('슬프고'),
#  np.str_('생애'),
#  np.str_('사랑스러운'),
#  np.str_('사는'),
#  np.str_('뻔하고'),
#  np.str_('보니까'),
#  np.str_('무엇을'),
#  np.str_('모든게'),
#  np.str_('만들고'),
#  np.str_('좀더'),
#  np.str_('잼있게'),
#  np.str_('잔잔하고'),
#  np.str_('오'),
#  np.str_('않지만'),
#  np.str_('말을'),
#  np.str_('더빙'),
#  np.str_('단지'),
#  np.str_('그래'),
#  np.str_('결말도'),
#  np.str_('3점'),
#  np.str_('프랑스'),
#  np.str_('작품을'),
#  np.str_('여주'),
#  np.str_('아까워'),
#  np.str_('떠나서'),
#  np.str_('같아'),
#  np.str_('현실'),
#  np.str_('잘만든'),
#  np.str_('오래'),
#  np.str_('옛날에'),
#  np.str_('알바'),
#  np.str_('봣는데'),
#  np.str_('가'),
#  np.str_('인생의'),
#  np.str_('아오'),
#  np.str_('싫다'),
#  np.str_('실제'),
#  np.str_('수준이'),
#  np.str_('만들었다'),
#  np.str_('둘다'),
#  np.str_('누구나'),
#  np.str_('글쎄'),
#  np.str_('극장판'),
#  np.str_('같아서'),
#  np.str_('ㄷㄷ'),
#  np.str_('ooo기'),
#  np.str_('한데'),
#  np.str_('젤'),
#  np.str_('작가'),
#  np.str_('있나'),
#  np.str_('속에'),
#  np.str_('생각나는'),
#  np.str_('무서운'),
#  np.str_('못했다'),
#  np.str_('몇번을'),
#  np.str_('대사가'),
#  np.str_('늘'),
#  np.str_('남자가'),
#  np.str_('그럼'),
#  np.str_('평생'),
#  np.str_('짜증'),
#  np.str_('지루'),
#  np.str_('지'),
#  np.str_('유쾌하고'),
#  np.str_('보고싶다'),
#  np.str_('라고'),
#  np.str_('되고'),
#  np.str_('남을'),
#  np.str_('힘들다'),
#  np.str_('처럼'),
#  np.str_('집에서'),
#  np.str_('재밌었음'),
#  np.str_('어릴적'),
#  np.str_('시절'),
#  np.str_('분위기'),
#  np.str_('보고나면'),
#  np.str_('드럽게'),
#  np.str_('긴'),
#  np.str_('건지'),
#  np.str_('흔한'),
#  np.str_('작가가'),
#  np.str_('이런영화가'),
#  np.str_('멋지다'),
#  np.str_('나서'),
#  np.str_('초반에'),
#  np.str_('좋았던'),
#  np.str_('음악과'),
#  np.str_('않아'),
#  np.str_('아깝지'),
#  np.str_('생각하고'),
#  np.str_('생각없이'),
#  np.str_('사랑은'),
#  np.str_('보고싶은'),
#  np.str_('모습'),
#  np.str_('말로'),
#  np.str_('만화'),
#  np.str_('따뜻해지는'),
#  np.str_('다시한번'),
#  np.str_('그걸'),
#  np.str_('ㅇㅇ'),
#  np.str_('2'),
#  ...]

# %%
# 단어사전 기반으로 수치화 진행(벡터화)
X_train_vec = vectorizer(train_txt)
X_test_vec = vectorizer(test_txt)

# %%
X_train_vec[0]
# 데이터의 크기는 모두 길이가 10이다. -> output_sequence_length = 10 으로 설정했기 때문에
# 모든 데이터의 길이가 10으로 지정되었다. (모델에 사용하려면 모든 데이터의 길이가 동일해야 한다.)
# 또한 수치가 모두 int인 이유는 반환 타입을 int로 설정했기 떄문
# Out:
# <tf.Tensor: shape=(10,), dtype=int64, numpy=array([  37,  914,    5,    1, 1077,    0,    0,    0,    0,    0])>

# %%
train_txt[0]
# Out:
# '아 더빙.. 진짜 짜증나네요 목소리'

# %%
print(X_train_vec.shape)
print(X_test_vec.shape)
# Out:
# (149995, 10)
# (49997, 10)

# %% [markdown]
# ### 순환신경망 사용
# -  순환신경망을 사용할 떄 데이터의 크기는 (샘플링의수, 순환횟수(데이터의 길이), 특성의수)로 이루어져 있음
# - 만약에 순환신경망에 데이터를 넣을 때 (샘플링의 수, 순환횟수(데이터의 길이))로만 이루어져 있을 경우 특성의 수를 1로 지정하여 사용할 수 있음

# %%
# 도구 불러오기
from tensorflow.keras import Sequential
from tensorflow.keras.layers import InputLayer, Dense, SimpleRNN, LSTM

# %%
# SimpleRNN 을 사용
# 뼈대 쌓기
rnn_model = Sequential()

# 입력층 쌓기
rnn_model.add(InputLayer(shape=(10,1))) # 데이터의 길이가 10이기 때문
# RNN층 쌓기
rnn_model.add(SimpleRNN(units=64, activation='tanh'))
# MLP층 쌓기
rnn_model.add(Dense(units=64, activation='relu'))
# 출력층 쌓기
rnn_model.add(Dense(units=1, activation='sigmoid'))
# 이진분류(긍정/부정) -> units = 1 / activation = 'sigmoid'

# %%
# 학습방법 및 평가방법 설정
rnn_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# 모델 학습 (rnn_his 정의)
rnn_his = rnn_model.fit(
    X_train_vec,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

# 성능 시각화
plt.figure(figsize=(15,5))
plt.plot(rnn_his.history['accuracy'],label='acc')
plt.plot(rnn_his.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.5090 - loss: 0.6950 - val_accuracy: 0.5071 - val_loss: 0.6930
# Epoch 2/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step - accuracy: 0.5044 - loss: 0.6934 - val_accuracy: 0.5056 - val_loss: 0.6933
# Epoch 3/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - accuracy: 0.5059 - loss: 0.6931 - val_accuracy: 0.5064 - val_loss: 0.6931
# Epoch 4/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.5035 - loss: 0.6932 - val_accuracy: 0.5050 - val_loss: 0.6931
# Epoch 5/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.5041 - loss: 0.6932 - val_accuracy: 0.4977 - val_loss: 0.6932
# Epoch 6/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - accuracy: 0.5045 - loss: 0.6932 - val_accuracy: 0.5064 - val_loss: 0.6931
# Epoch 7/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 28s 7ms/step - accuracy: 0.5022 - loss: 0.6931 - val_accuracy: 0.5054 - val_loss: 0.6931
# Epoch 8/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 6ms/step - accuracy: 0.5049 - loss: 0.6931 - val_accuracy: 0.5062 - val_loss: 0.6932
# Epoch 9/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.5044 - loss: 0.6932 - val_accuracy: 0.5060 - val_loss: 0.6930
# Epoch 10/10
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.5033 - loss: 0.6931 - val_accuracy: 0.5054 - val_loss: 0.6931

# %% [markdown]
# ### LSTM 모델 사

# %%
# LSTM 신경망 쌓기
# 뼈대 생성
lstm_model=Sequential()
# 입력층 쌓기
lstm_model.add(InputLayer(shape=(10,1)))
# LSTM층 쌓기
lstm_model.add(LSTM(units=64, activation='tanh'))
# MLP층 쌓기
lstm_model.add(Dense(units=64, activation='relu'))
# 출력층 쌓기
lstm_model.add(Dense(units=1, activation='sigmoid'))

# %%
# 학습방법 및 평가방법 설정
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
lstm_model.fit(
    X_train_vec, y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=64
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.5209 - loss: 0.6919 - val_accuracy: 0.5351 - val_loss: 0.6906
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.5281 - loss: 0.6909 - val_accuracy: 0.5277 - val_loss: 0.6904
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.5293 - loss: 0.6907 - val_accuracy: 0.5288 - val_loss: 0.6907
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.5329 - loss: 0.6900 - val_accuracy: 0.5360 - val_loss: 0.6901
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.5346 - loss: 0.6897 - val_accuracy: 0.5371 - val_loss: 0.6893
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5353 - loss: 0.6894 - val_accuracy: 0.5342 - val_loss: 0.6900
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5375 - loss: 0.6891 - val_accuracy: 0.5388 - val_loss: 0.6889
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5391 - loss: 0.6884 - val_accuracy: 0.5364 - val_loss: 0.6886
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5408 - loss: 0.6879 - val_accuracy: 0.5424 - val_loss: 0.6879
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.5418 - loss: 0.6873 - val_accuracy: 0.5398 - val_loss: 0.6880
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.5418 - loss: 0.6870 - val_accuracy: 0.5368 - val_loss: 0.6889
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.5419 - loss: 0.6868 - val_accuracy: 0.5383 - val_loss: 0.6871
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5443 - loss: 0.6864 - val_accuracy: 0.5417 - val_loss: 0.6870
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5429 - loss: 0.6863 - val_accuracy: 0.5423 - val_loss: 0.6875
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5437 - loss: 0.6862 - val_accuracy: 0.5436 - val_loss: 0.6865
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5447 - loss: 0.6858 - val_accuracy: 0.5458 - val_loss: 0.6866
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5458 - loss: 0.6854 - val_accuracy: 0.5467 - val_loss: 0.6860
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.5461 - loss: 0.6852 - val_accuracy: 0.5441 - val_loss: 0.6860
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.5471 - loss: 0.6850 - val_accuracy: 0.5443 - val_loss: 0.6863
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.5457 - loss: 0.6849 - val_accuracy: 0.5416 - val_loss: 0.6858

# %%
# 성능 시각화 진행
plt.figure(figsize=(15,5))
plt.plot(lstm_model.history.history['accuracy'],label='acc')
plt.plot(lstm_model.history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# ### 결과 확인
# - simpleRNN보다는 LSTM모델이 성능이 조금 더 높은 것을 확인
# - 하지만 데이터 전처리를 하지 않았기 때문에 특정 이상의 성능을 기대하기 어렵다
# - 결국은 데이터 전처리의 유무가 결과에 영향을 크게 준다는 것을 알 수 있다.

# %%
# 조금이라도 성능 개선을 위해 Embedding 층 쌓아보기
# 임베딩 레이어
from tensorflow.keras.layers import Embedding

# %%
# LSTM모델과 Embedding레이어를 활용한 학습 진행
emb_model = Sequential()

# 임베딩 레이어 추가
emb_model.add(Embedding(5000,50))
# 단어 사전의 수가 5000개이기 때문에 5000으로 설정
# 벡터의 크기를 50으로 지정한 것은 정답이 아님 -> 임의의 개수로 지정하되 너무 크거나 작지 않도록 설정
# LSTM층 쌓기
emb_model.add(LSTM(units=64, activation='tanh'))
# MLP층 쌓기
emb_model.add(Dense(units=64, activation='relu'))
# 출력층 쌓기
emb_model.add(Dense(units=1, activation='sigmoid'))

# %%
# 학습방법 설정
emb_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# 학습진행
emb_his = emb_model.fit(
    X_train_vec, y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=64
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7366 - loss: 0.4922 - val_accuracy: 0.7504 - val_loss: 0.4648
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7672 - loss: 0.4420 - val_accuracy: 0.7679 - val_loss: 0.4546
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7767 - loss: 0.4241 - val_accuracy: 0.7641 - val_loss: 0.4547
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7860 - loss: 0.4064 - val_accuracy: 0.7651 - val_loss: 0.4608
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7940 - loss: 0.3910 - val_accuracy: 0.7648 - val_loss: 0.4749
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8023 - loss: 0.3760 - val_accuracy: 0.7597 - val_loss: 0.5000
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8075 - loss: 0.3614 - val_accuracy: 0.7619 - val_loss: 0.5398
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8150 - loss: 0.3455 - val_accuracy: 0.7570 - val_loss: 0.5644
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8227 - loss: 0.3298 - val_accuracy: 0.7512 - val_loss: 0.6069
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8292 - loss: 0.3151 - val_accuracy: 0.7451 - val_loss: 0.6656
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8361 - loss: 0.3014 - val_accuracy: 0.7484 - val_loss: 0.7044
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8410 - loss: 0.2895 - val_accuracy: 0.7459 - val_loss: 0.7624
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8472 - loss: 0.2784 - val_accuracy: 0.7409 - val_loss: 0.8465
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8509 - loss: 0.2689 - val_accuracy: 0.7427 - val_loss: 0.8923
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8538 - loss: 0.2625 - val_accuracy: 0.7380 - val_loss: 0.9791
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8579 - loss: 0.2545 - val_accuracy: 0.7388 - val_loss: 0.9809
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8625 - loss: 0.2481 - val_accuracy: 0.7422 - val_loss: 1.0502
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8654 - loss: 0.2420 - val_accuracy: 0.7390 - val_loss: 1.0940
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8674 - loss: 0.2360 - val_accuracy: 0.7410 - val_loss: 1.1395
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8712 - loss: 0.2303 - val_accuracy: 0.7369 - val_loss: 1.2855

# %% [markdown]
# ### 결론 정리
# - 텍스트 데이터를 다룰 때에는 전처리 작업이 결과에 영향을 많이 미치는 것을 확인할 수 있었다.
# - 결국 데이터를 다룰 대 전처리 작업의 유무에 따라 결과에 영향을 많이 미치기 때문에 전처리 작업도 매우 중요하다.

# %% [markdown]
# ### GRU 모델
# - LSTM의 과도한 연산으로 인한 학습속도를 개선하기 위해 나온 모델
# - 성능적인 측면을 개선하기 위해 나온 모델은 아니기 때문에 성능적인 측면에서 개선이 되었다고는 하기 어려움

# %%
# 도구 불러오기
from tensorflow.keras.layers import GRU

# %% [markdown]
# ### 허깅페이스
# - 인공지능 관련 데이터셋, 테스팅 공간 등을 공유하는 거대 커뮤니티 웹서비스
# - 여러가지 모델을 공유하여 사용할 수 있기 때문에 내가 다른사람이 학습시켜놓은 모델을 가져가다 사용이 가능하다.
# - 내가 학습시킨 모델도 업로드하여 다른사람이 사용할 수 있도록 설정 가

# %% [markdown]
# ### 시퀀스- 투-시퀀스
# -번역기에서 대표적으로 사용되는 몯ㄹ
# - 인코더와 디코더라는 두개의 모듈로 구성
# - 인코더 : 입력된 문장의 모든 단어를 학습하여 정보를 압축하여 의미를 해석하는 모델 (의미를 해석하는 모델)
# - 디코더 : 데이터를 받아서 번역된 단어를 순차적으로 출력하는 모델 (출력하는 모델)

# %% [markdown]
# ### Transformer
#   - 필요한 것은 주의 집중(Attention is All You Need) 논문으로 2017년 발표
#   - 순환과 컨볼루션을 완전히 배제하고 오로지 Attention 메커니즘에만 기반을 둔 새롭고 단순한 신경망 아키텍처
#
#   - 인코더와 디코더로 구성
#   - 인코더
#     - 트랜스포머는 하이퍼파라미터인 num_layers 개수의 인코더 층을 쌓음
#     - 하나의 인코더 층은 크게 셀프 어텐션과 피드 포워드 신경망의 2개의 서브층(sublayer)으로 구성
#       - Multi-head Self-Attention : 셀프 어텐션을 병렬적으로 사용
#       - Position-wise FFNN : 일반적인 피드 포워드 신경망
#     - 인코딩의 출력은 디코더로 전달
#
#   - 디코더
#     - num_layers 개수의 디코더 층을 쌓음
#     - 인코더에서 보낸 출력을 디코더 층의 연산에 사용
#     - 디코더는 3개 층으로 구성
#       - Masked Multi-head Self-Attention (Self Attention과 Look-ahead mask): 현재 시점의 예측에서 현재 시점보다 미래에 있는 단어들을 참고하지 못하도록 룩-어헤드 마스크(look-ahead mask)를 사용
#         - 트랜스포머는 문장 행렬로 입력을 한 번에 받으므로 현재 시점의 단어를 예측하고자 할 때, 입력 문장 행렬로부터 미래 시점의 단어까지도 참고할 수 있는 현상이 발생
#       - Multi-head Self-Attention (Encoder-Decoder Attention) : 멀티 헤드 어텐션을 수행
#       - Position-wise FFNN
#
# <center>
# <img src="https://arome1004.cafe24.com/images/deeplearning/transformer_attention_overview.png" width=60%>
# </center>

# %% [markdown]
# ## Transformer 구조
#
# > **Positional Encoding (위치 인코딩)**
# > - Self-Attention 기반 모델은 입력 순서를 순차적으로 처리하지 못 함
# > - 이에 대해 **<U>토큰 간 순서 정보**</U>를 알려주기 위함 (한 문장을 병렬로 처리하면서도 각 단어의 위치를 인지하게 됨)
#
# > **Encoder Self-Attention**
# > - 인코더는 **<U>입력 문장의 모든 단어 간의 관계**</U>를 계산하여, 문장 전체에서 중요한 정보를 파악
#
# > **Add & Norm**
# > - 출력에 원래 입력을 **<U>더하고, 값을 정규화**</U>하여 안정된 학습을 도움
# > - ResNet - Skip Connection 개념 차용
#
# > **Feed Forward**
# > - 활성화 함수(ReLU)를 사용해 입력을 처리해서, 비선형성을 통해 모델이 더 복잡한 패턴을 학습할 수 있게 만드는 **<U>완전 연결 신경망**</U> (쉽게 MLP 떠올리면 됨)
#
# > **Masked Decoder Self-Attention**
# > - 디코더가 예측할 때 미래 단어를 **<U>참조하지 못하게 막아**</U>, 이전 단어들만을 사용해 순차적으로 예측
#
# > **Encoder-Decoder Self-Attention**
# > - Seq2Seq Attention (Bahdanau/Luong)에서 발전된 형태
# > - **<U>디코더가 인코더의 출력을 참조**</U>하여,  입력 문장과의 관계를 기반으로 더 정확한 출력을 생성

# %%
# transform
# !pip install transformers[torch]==4.42

# %% [markdown]
# ### 문장번역 모델 사용

# %%
from transformers import pipeline

# %%
# Temporarily uninstall and reinstall transformers to address internal KeyError: 'translation'
# This issue often arises from a corrupted or incomplete library installation.
# !pip uninstall -y transformers
# !pip install transformers[torch]==4.42

from transformers import pipeline
# 번역 모델 사용
translator = pipeline(
    task = 'translation_ko_to_en', # 한국어에서 영어로 번역
    model = 'Helsinki-NLP/opus-mt-ko-en' # 원하는 모델 불러서 지정(모델 명)
)
# Out:
# Found existing installation: transformers 4.42.0
# Uninstalling transformers-4.42.0:
#   Successfully uninstalled transformers-4.42.0
# Collecting transformers==4.42 (from transformers[torch]==4.42)
#   Using cached transformers-4.42.0-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (0.36.2)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42->transformers[torch]==4.42) (4.67.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from transformers[torch]==4.42) (2.10.0+cu128)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]==4.42) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.21.0->transformers[torch]==4.42) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42->transformers[torch]==4.42) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42->transformers[torch]==4.42) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42->transformers[torch]==4.42) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->transformers[torch]==4.42) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->transformers[torch]==4.42) (1.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42->transformers[torch]==4.42) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42->transformers[torch]==4.42) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42->transformers[torch]==4.42) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42->transformers[torch]==4.42) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->transformers[torch]==4.42) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->transformers[torch]==4.42) (3.0.3)
# Using cached transformers-4.42.0-py3-none-any.whl (9.3 MB)
# Installing collected packages: transformers
# Successfully installed transformers-4.42.0
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/842k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
# 번역하기
text = '나는 오늘 집에 가서 쉬고 싶어요.'
translator(text)
# Out:
# [{'translation_text': 'I want to go home today and rest.'}]

# %% [markdown]
# ### transformer 종류
# - 넓은 관점에서 트랜스포머 모델은 세 가지로 범주화 할 수 있음
#
# > BERT 계열
# > - Transformer 모델의 Encoder만 활용
# > - 입력 전체를 한 번에 보고, 양방향으로 학습
# > - 대표 모델 : BERT, ELECTRA 등
# > - 주 사용처 : 문장 분류, 개체명 인식, 문장 유사도 등 전체 문장에 대한 이해를 요구하는 작업
# >     - 빠른 추론과 가벼운 배포가 장점, 분류/검색/추천/임베딩 등 읽기 중심의 task에 많이 쓰임
#
# > Seq2Seq 계열
# > - Sequence-to-Sequence(Encoding → Decoding) 구조
# > - 다양한 생성, 이해 작업에 강점을 가짐
# > - 대표 모델 : T5, BART 등
# > - 주 사용처 : 제로샷 분류, 요약/번역/재작성 등
# >     - 다수 task(요약, 번역, 생성 등)을 하나의 모델로 운영 할 때 자주 사용
#
# > GPT 계열
# > - Transformer 모델의 Decoder만 활용
# > - 입력을 순차적으로 처리하며 다음 토큰 예측(순방향)
# > - 대표 모델 : GPT, GPT-2, CTRL, GPT-3, GPT-4 등
# > - 주 사용처 : 텍스트 생성, 대화형 에이전트 등
# >     - 창의적 생성이 장점, 프롬프트 엔지니어링이 중요할 때 선호
# ![image.png](data:image/png;base64,...)

# %%
# 한국어 분류 모델 사용(Ko Electra) pipeline 로드
classfier = pipeline(
    task = 'sentiment-analysis', # 감정분석
    model = 'daekeun-ml/koelectra-small-v3-nsmc',
    device=0
)
# Out:
# config.json:   0%|          | 0.00/914 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/56.5M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# 감정 분석 진행
# 0 -> 부정 / 1 -> 긍정
test_text = '너는 싫어',
classfier(test_text)
# Out:
# {'label': '0', 'score': 0.5566043257713318}
